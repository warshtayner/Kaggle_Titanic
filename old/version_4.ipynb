# %%
#main
import pandas as pd
import numpy as np

#plot
import seaborn as sns
from matplotlib import pyplot as plt

#dop
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

#ML
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier

#metric
from sklearn.metrics import mean_squared_error as mse, r2_score as r2

#test
from collections import Counter

# %%
PATH_TO_TRAIN = 'csv/train.csv'
PATH_TO_TASK = 'csv/test.csv'

# %%
train = pd.read_csv(PATH_TO_TRAIN, index_col='PassengerId')
task = pd.read_csv(PATH_TO_TASK, index_col='PassengerId')

# %%
task.info()
task.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
y_train_mean = train['Survived']

# %%
df = pd.concat([train.drop('Survived', axis=1), task])

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   int64
#  1   Name      1309 non-null   object
#  2   Sex       1309 non-null   object
#  3   Age       1046 non-null   float64
#  4   SibSp     1309 non-null   int64
#  5   Parch     1309 non-null   int64
#  6   Ticket    1309 non-null   object
#  7   Fare      1308 non-null   float64
#  8   Cabin     295 non-null    object
#  9   Embarked  1307 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 112.5+ KB
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S

# %% [markdown]
# Зависимость выживаемости от признаков
# ---

# %%
plt.figure(figsize = [20, 15])
plt.subplot(3, 3, 1)
sns.histplot(data = train, x = train['Sex'], hue = train['Survived'], multiple = 'dodge')
plt.subplot(3, 3, 2)
sns.histplot(data = train, x = train['Pclass'], hue = train['Survived'], multiple = 'dodge')
plt.subplot(3, 3, 3)
sns.histplot(data = train, x = train['Embarked'], hue = train['Survived'], multiple = 'dodge')
plt.subplot(3, 3, 4)
sns.histplot(data = train, x = train['Age'], hue = train['Survived'], multiple = 'dodge')
plt.subplot(3, 3, 5)
sns.histplot(data = train, x = train['SibSp'], hue = train['Survived'], multiple = 'dodge')
plt.subplot(3, 3, 6)
sns.histplot(data = train, x = train['Parch'], hue = train['Survived'], multiple = 'dodge')
plt.plot();

# %% [markdown]
# способ вытянуть значения из str переменной

# %%
df['Title'] = df['Name'].str.extract(' ([A-z]+)\.')

# %% [markdown]
# ---

# %%
df.replace({'male' :0, 'female' :1}, inplace=True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   int64
#  1   Name      1309 non-null   object
#  2   Sex       1309 non-null   int64
#  3   Age       1046 non-null   float64
#  4   SibSp     1309 non-null   int64
#  5   Parch     1309 non-null   int64
#  6   Ticket    1309 non-null   object
#  7   Fare      1308 non-null   float64
#  8   Cabin     295 non-null    object
#  9   Embarked  1307 non-null   object
#  10  Title     1309 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB
#              Pclass                                               Name  Sex  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris    0
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 3                 3                             Heikkinen, Miss. Laina    1
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 5                 3                           Allen, Mr. William Henry    0
#
#               Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1            22.0      1      0         A/5 21171   7.2500   NaN        S
# 2            38.0      1      0          PC 17599  71.2833   C85        C
# 3            26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4            35.0      1      0            113803  53.1000  C123        S
# 5            35.0      0      0            373450   8.0500   NaN        S
#
#             Title
# PassengerId
# 1              Mr
# 2             Mrs
# 3            Miss
# 4             Mrs
# 5              Mr

# %% [markdown]
# Заполнение пропусков признака 'Age'
# ---
# ---
# Одной медианной по всей выборке нельзя это сильно изменит параметры нормального распределения

# %%
index_nan_age = list(df['Age'][df['Age'].isnull()].index)

for i in index_nan_age:
    age_med = np.nanmedian(df['Age'][(df['Sex'] == df.loc[i]['Sex']) & (df["Pclass"] == df.loc[i]['Pclass'])])
    df.loc[i, 'Age'] = age_med

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   int64
#  1   Name      1309 non-null   object
#  2   Sex       1309 non-null   int64
#  3   Age       1309 non-null   float64
#  4   SibSp     1309 non-null   int64
#  5   Parch     1309 non-null   int64
#  6   Ticket    1309 non-null   object
#  7   Fare      1308 non-null   float64
#  8   Cabin     295 non-null    object
#  9   Embarked  1307 non-null   object
#  10  Title     1309 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 155.0+ KB

# %%
test_age = train.copy()

# %%
test_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 115.8+ KB

# %%
for i in list(df[df.index <= test_age.index[-1]].index):
    test_age.loc[i, 'Age'] = df.loc[i, 'Age']

# %%
plt.figure(figsize = [20, 5])
plt.title('Сравнение до после заполнение nan')
plt.subplot(1, 2, 2)
sns.histplot(data = test_age, x = test_age['Age'], hue = test_age['Survived'], multiple = 'layer')
plt.subplot(1, 2, 1)
sns.histplot(data = train, x = train['Age'], hue = train['Survived'], multiple = 'layer')
plt.plot()
# Out:
# []

# %%
test_age['Age_group'] = test_age['Age'].map(lambda age: int(age // 14))
sns.histplot(data = test_age, x = test_age['Age_group'], hue = test_age['Survived'], multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='Age_group', ylabel='Count'>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   int64
#  1   Name      1309 non-null   object
#  2   Sex       1309 non-null   int64
#  3   Age       1309 non-null   float64
#  4   SibSp     1309 non-null   int64
#  5   Parch     1309 non-null   int64
#  6   Ticket    1309 non-null   object
#  7   Fare      1308 non-null   float64
#  8   Cabin     295 non-null    object
#  9   Embarked  1307 non-null   object
#  10  Title     1309 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 155.0+ KB
#              Pclass                                               Name  Sex  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris    0
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 3                 3                             Heikkinen, Miss. Laina    1
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 5                 3                           Allen, Mr. William Henry    0
#
#               Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1            22.0      1      0         A/5 21171   7.2500   NaN        S
# 2            38.0      1      0          PC 17599  71.2833   C85        C
# 3            26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4            35.0      1      0            113803  53.1000  C123        S
# 5            35.0      0      0            373450   8.0500   NaN        S
#
#             Title
# PassengerId
# 1              Mr
# 2             Mrs
# 3            Miss
# 4             Mrs
# 5              Mr

# %%
df['Age_group'] = df['Age'].map(lambda age: int(age // 14))

# %% [markdown]
# ---
#
#
# Работа с 'Title'
# ---

# %%
test_age['Title'] = df[df.index <= test_age.index[-1]]['Title']

# %%
plt.figure(figsize = [20, 7])
sns.histplot(data = test_age, x = test_age['Title'], hue = test_age['Survived'], multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='Title', ylabel='Count'>

# %%
test_age.groupby('Title').mean()['Survived'].sort_values()
# Out:
# Title
# Capt        0.000000
# Don         0.000000
# Jonkheer    0.000000
# Rev         0.000000
# Mr          0.156673
# Dr          0.428571
# Col         0.500000
# Major       0.500000
# Master      0.575000
# Miss        0.697802
# Mrs         0.792000
# Mlle        1.000000
# Mme         1.000000
# Countess    1.000000
# Ms          1.000000
# Lady        1.000000
# Sir         1.000000
# Name: Survived, dtype: float64

# %%
df['Title'].replace(['Dr', 'Col', 'Major', 'Rev', 'Jonkheer', 'Don', 'Capt'], 'Mr', inplace=True)
df['Title'].replace(['Sir'], 'Master', inplace=True)
df['Title'].replace(['Lady', 'Ms', 'Countess', 'Mme', 'Mlle', 'Mrs', 'Dona'], 'Miss', inplace=True)

# %%
test_age['Title'].replace(['Dr', 'Col', 'Major', 'Rev', 'Jonkheer', 'Don', 'Capt'], 'Mr', inplace=True)
test_age['Title'].replace(['Sir'], 'Master', inplace=True)
test_age['Title'].replace(['Lady', 'Ms', 'Countess', 'Mme', 'Mlle', 'Mrs', 'Dona'], 'Miss', inplace=True)

# %%
test_age.groupby('Title').mean()['Survived']
# Out:
# Title
# Master    0.585366
# Miss      0.741214
# Mr        0.160149
# Name: Survived, dtype: float64

# %%
plt.figure(figsize = [10, 5])
sns.histplot(data = test_age, x = test_age['Title'], hue = test_age['Survived'], multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='Title', ylabel='Count'>

# %% [markdown]
# ---
# Работа с признаком Cabin
# ---
# ---

# %%
df['Cabin'].str.extract('(\w)').value_counts()
# Out:
# C    94
# B    65
# D    46
# E    41
# A    22
# F    21
# G     5
# T     1
# dtype: int64

# %%
df['Cabin'] = df['Cabin'].str.extract('(\w)')

# %%
df.loc[df['Cabin'].isnull(), 'Cabin'] = 'U' # U is unknown

# %%
df['Cabin'].value_counts().sort_index()
# Out:
# A      22
# B      65
# C      94
# D      46
# E      41
# F      21
# G       5
# T       1
# U    1014
# Name: Cabin, dtype: int64

# %% [markdown]
# ![img](./ddf3070c69e0450184e35790f72917d1.jpeg)

# %%
df[df['Cabin'] == 'T']
# Out:
#              Pclass                          Name  Sex   Age  SibSp  Parch  \
# PassengerId
# 340               1  Blackwell, Mr. Stephen Weart    0  45.0      0      0
#
#              Ticket  Fare Cabin Embarked Title  Age_group
# PassengerId
# 340          113784  35.5     T        S    Mr          3

# %%
df.loc[df['Cabin'] == 'T', 'Cabin'] = 'B'

# %%
test = df[df.index <= train.index[-1]].copy()
test['Survived'] = train['Survived']

# %%
plt.figure(figsize = [10, 5])
sns.histplot(data=test, x=test['Cabin'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='Count'>

# %%
plt.figure(figsize = [10, 5])
sns.histplot(data=test, x=test[test['Cabin'] != 'U']['Cabin'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='Count'>

# %% [markdown]
# ЧТО - ТО не как

# %%
df.loc[df['Cabin'] != 'U', 'Cabin'] = 'K' # K is Know
test.loc[test['Cabin'] != 'U', 'Cabin'] = 'K' # K is Know

# %%
plt.figure(figsize = [10, 5])
sns.histplot(data=test, x=test['Cabin'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='Count'>

# %% [markdown]
# ---
# Работа с признаками SibSp Parch
# ---
# ---

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pclass     1309 non-null   int64
#  1   Name       1309 non-null   object
#  2   Sex        1309 non-null   int64
#  3   Age        1309 non-null   float64
#  4   SibSp      1309 non-null   int64
#  5   Parch      1309 non-null   int64
#  6   Ticket     1309 non-null   object
#  7   Fare       1308 non-null   float64
#  8   Cabin      1309 non-null   object
#  9   Embarked   1307 non-null   object
#  10  Title      1309 non-null   object
#  11  Age_group  1309 non-null   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 165.2+ KB
#              Pclass                                               Name  Sex  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris    0
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 3                 3                             Heikkinen, Miss. Laina    1
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 5                 3                           Allen, Mr. William Henry    0
#
#               Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1            22.0      1      0         A/5 21171   7.2500     U        S
# 2            38.0      1      0          PC 17599  71.2833     K        C
# 3            26.0      0      0  STON/O2. 3101282   7.9250     U        S
# 4            35.0      1      0            113803  53.1000     K        S
# 5            35.0      0      0            373450   8.0500     U        S
#
#             Title  Age_group
# PassengerId
# 1              Mr          1
# 2            Miss          2
# 3            Miss          1
# 4            Miss          2
# 5              Mr          2

# %%
df['Family_size'] = df['Parch'] + df['SibSp'] + 1

# %%
test = df[df.index <= train.index[-1]].copy()
test['Survived'] = train['Survived']

# %%
plt.figure(figsize=[10, 7])
sns.histplot(data=test, x=test['Family_size'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Family_size', ylabel='Count'>

# %%
test.groupby('Family_size').mean()['Survived']
# Out:
# Family_size
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %%
test['Fam_gp'] = 0
test.loc[test['Family_size'] > 7, 'Fam_gp'] = 0
test.loc[(test['Family_size'] > 4)  & (test['Family_size'] < 8), 'Fam_gp'] = 1
test.loc[(test['Family_size'] > 1)  & (test['Family_size'] < 5), 'Fam_gp'] = 3
test.loc[test['Family_size'] == 1, 'Fam_gp'] = 2

# %%
plt.figure(figsize=[10, 7])
sns.histplot(data=test, x=test['Fam_gp'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Fam_gp', ylabel='Count'>

# %%
df['Fam_gp'] = 0
df.loc[df['Family_size'] > 7, 'Fam_gp'] = 0
df.loc[(df['Family_size'] > 4)  & (df['Family_size'] < 8), 'Fam_gp'] = 1
df.loc[(df['Family_size'] > 1)  & (df['Family_size'] < 5), 'Fam_gp'] = 3
df.loc[df['Family_size'] == 1, 'Fam_gp'] = 2

# %% [markdown]
# ---
# Работа с признаком Ticket
# ---
# ___

# %% [markdown]
# !!! получить датафрейм ticket с количеством одинаковых признаков для каждого объекта

# %%
 df.groupby('Ticket')['Ticket'].transform('count') # Полезный метод
# Out:
# PassengerId
# 1       1
# 2       2
# 3       1
# 4       2
# 5       1
#        ..
# 1305    1
# 1306    3
# 1307    1
# 1308    1
# 1309    3
# Name: Ticket, Length: 1309, dtype: int64

# %%
test['Identical_tickets'] = test.groupby('Ticket')['Ticket'].transform('count')

# %%
plt.figure(figsize=[10, 5])
sns.histplot(data=test, x=test['Identical_tickets'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Identical_tickets', ylabel='Count'>

# %%
test.groupby('Identical_tickets').mean()['Survived']
# Out:
# Identical_tickets
# 1    0.297989
# 2    0.574468
# 3    0.698413
# 4    0.500000
# 5    0.000000
# 6    0.000000
# 7    0.238095
# Name: Survived, dtype: float64

# %%
test['IT'] = 0
test.loc[test['Identical_tickets'] == 1, 'IT'] = 1
test.loc[(test['Identical_tickets'] > 1) & (test['Identical_tickets'] < 5), 'IT'] = 2

# %%
plt.figure(figsize=[7, 7])
sns.histplot(data=test, x=test['IT'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='IT', ylabel='Count'>

# %%
df['Identical_tickets'] = df.groupby('Ticket')['Ticket'].transform('count')
df['IT'] = 0
df.loc[df['Identical_tickets'] == 1, 'IT'] = 1
df.loc[(df['Identical_tickets'] > 1) & (df['Identical_tickets'] < 5), 'IT'] = 2

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pclass             1309 non-null   int64
#  1   Name               1309 non-null   object
#  2   Sex                1309 non-null   int64
#  3   Age                1309 non-null   float64
#  4   SibSp              1309 non-null   int64
#  5   Parch              1309 non-null   int64
#  6   Ticket             1309 non-null   object
#  7   Fare               1308 non-null   float64
#  8   Cabin              1309 non-null   object
#  9   Embarked           1307 non-null   object
#  10  Title              1309 non-null   object
#  11  Age_group          1309 non-null   int64
#  12  Family_size        1309 non-null   int64
#  13  Fam_gp             1309 non-null   int64
#  14  Identical_tickets  1309 non-null   int64
#  15  IT                 1309 non-null   int64
# dtypes: float64(2), int64(9), object(5)
# memory usage: 206.1+ KB
#              Pclass                                               Name  Sex  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris    0
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 3                 3                             Heikkinen, Miss. Laina    1
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 5                 3                           Allen, Mr. William Henry    0
#
#               Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1            22.0      1      0         A/5 21171   7.2500     U        S
# 2            38.0      1      0          PC 17599  71.2833     K        C
# 3            26.0      0      0  STON/O2. 3101282   7.9250     U        S
# 4            35.0      1      0            113803  53.1000     K        S
# 5            35.0      0      0            373450   8.0500     U        S
#
#             Title  Age_group  Family_size  Fam_gp  Identical_tickets  IT
# PassengerId
# 1              Mr          1            2       3                  1   1
# 2            Miss          2            2       3                  2   2
# 3            Miss          1            1       2                  1   1
# 4            Miss          2            2       3                  2   2
# 5              Mr          2            1       2                  1   1

# %% [markdown]
# ---
# Работа с признаком Embarked
# --
# ___

# %%
test['Identical_tickets'].value_counts()
# Out:
# 1    547
# 2    188
# 3     63
# 4     44
# 7     21
# 6     18
# 5     10
# Name: Identical_tickets, dtype: int64

# %%
test['Embarked'].fillna(test['Embarked'].mode()[0], inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
plt.figure(figsize=[10, 5])
sns.histplot(data=test, x=test['Embarked'], hue=test['Survived'], multiple='dodge');
test.groupby('Embarked').mean()['Survived']
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64

# %%
test['Emb_gr'] = 0
test.loc[test['Embarked'] == 'C', 'Emb_gr'] = 1

# %%
sns.histplot(data=test, x=test['Emb_gr'], hue=test['Survived'], multiple='dodge');
test.groupby('Emb_gr').mean()['Survived']
# Out:
# Emb_gr
# 0    0.344398
# 1    0.553571
# Name: Survived, dtype: float64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pclass             891 non-null    int64
#  1   Name               891 non-null    object
#  2   Sex                891 non-null    int64
#  3   Age                891 non-null    float64
#  4   SibSp              891 non-null    int64
#  5   Parch              891 non-null    int64
#  6   Ticket             891 non-null    object
#  7   Fare               891 non-null    float64
#  8   Cabin              891 non-null    object
#  9   Embarked           891 non-null    object
#  10  Title              891 non-null    object
#  11  Age_group          891 non-null    int64
#  12  Family_size        891 non-null    int64
#  13  Survived           891 non-null    int64
#  14  Fam_gp             891 non-null    int64
#  15  Identical_tickets  891 non-null    int64
#  16  IT                 891 non-null    int64
#  17  Emb_gr             891 non-null    int64
# dtypes: float64(2), int64(11), object(5)
# memory usage: 164.5+ KB

# %%
df['Emb_gr'] = 0
df.loc[df['Embarked'] == 'C', 'Emb_gr'] = 1

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pclass             891 non-null    int64
#  1   Name               891 non-null    object
#  2   Sex                891 non-null    int64
#  3   Age                891 non-null    float64
#  4   SibSp              891 non-null    int64
#  5   Parch              891 non-null    int64
#  6   Ticket             891 non-null    object
#  7   Fare               891 non-null    float64
#  8   Cabin              891 non-null    object
#  9   Embarked           891 non-null    object
#  10  Title              891 non-null    object
#  11  Age_group          891 non-null    int64
#  12  Family_size        891 non-null    int64
#  13  Survived           891 non-null    int64
#  14  Fam_gp             891 non-null    int64
#  15  Identical_tickets  891 non-null    int64
#  16  IT                 891 non-null    int64
#  17  Emb_gr             891 non-null    int64
# dtypes: float64(2), int64(11), object(5)
# memory usage: 164.5+ KB

# %% [markdown]
# ---
# Работа с признаком Fare
# --
# ___

# %%
test['Embarked'].mode()[0]
# Out:
# 'S'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pclass             1309 non-null   int64
#  1   Name               1309 non-null   object
#  2   Sex                1309 non-null   int64
#  3   Age                1309 non-null   float64
#  4   SibSp              1309 non-null   int64
#  5   Parch              1309 non-null   int64
#  6   Ticket             1309 non-null   object
#  7   Fare               1308 non-null   float64
#  8   Cabin              1309 non-null   object
#  9   Embarked           1309 non-null   object
#  10  Title              1309 non-null   object
#  11  Age_group          1309 non-null   int64
#  12  Family_size        1309 non-null   int64
#  13  Fam_gp             1309 non-null   int64
#  14  Identical_tickets  1309 non-null   int64
#  15  IT                 1309 non-null   int64
#  16  Emb_gr             1309 non-null   int64
# dtypes: float64(2), int64(10), object(5)
# memory usage: 216.4+ KB

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
df.describe()
# Out:
#             Pclass          Sex          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.355997    29.261398     0.498854     0.385027
# std       0.837836     0.478997    13.218275     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    22.000000     0.000000     0.000000
# 50%       3.000000     0.000000    26.000000     0.000000     0.000000
# 75%       3.000000     1.000000    36.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               Fare    Age_group  Family_size       Fam_gp  Identical_tickets  \
# count  1308.000000  1309.000000  1309.000000  1309.000000        1309.000000
# mean     33.295479     1.614973     1.883881     2.256684           2.101604
# std      51.758668     0.985346     1.583639     0.611907           1.779832
# min       0.000000     0.000000     1.000000     0.000000           1.000000
# 25%       7.895800     1.000000     1.000000     2.000000           1.000000
# 50%      14.454200     1.000000     1.000000     2.000000           1.000000
# 75%      31.275000     2.000000     2.000000     3.000000           3.000000
# max     512.329200     5.000000    11.000000     3.000000          11.000000
#
#                 IT       Emb_gr
# count  1309.000000  1309.000000
# mean      1.270435     0.206264
# std       0.618439     0.404777
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     0.000000
# 75%       2.000000     0.000000
# max       2.000000     1.000000

# %%
test['Fare'] = test['Fare'] / test['Identical_tickets']

# %%
test['Fare'].describe()
# Out:
# count    891.000000
# mean      17.788989
# std       21.218157
# min        0.000000
# 25%        7.762500
# 50%        8.850000
# 75%       24.288200
# max      221.779200
# Name: Fare, dtype: float64

# %%
sns.histplot(test['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %% [markdown]
# Большое количество по одному значению надо менять по log

# %%
test['Fare'] = test['Fare'].map(lambda n: np.log(n) if n > 0 else 0)

# %%
df[df['Fare'] == 0]
# Out:
#              Pclass                                   Name  Sex   Age  SibSp  \
# PassengerId
# 180               3                    Leonard, Mr. Lionel    0  36.0      0
# 264               1                  Harrison, Mr. William    0  40.0      0
# 272               3           Tornquist, Mr. William Henry    0  25.0      0
# 278               2            Parkes, Mr. Francis "Frank"    0  29.5      0
# 303               3        Johnson, Mr. William Cahoone Jr    0  19.0      0
# 414               2         Cunningham, Mr. Alfred Fleming    0  29.5      0
# 467               2                  Campbell, Mr. William    0  29.5      0
# 482               2       Frost, Mr. Anthony Wood "Archie"    0  29.5      0
# 598               3                    Johnson, Mr. Alfred    0  49.0      0
# 634               1          Parr, Mr. William Henry Marsh    0  42.0      0
# 675               2             Watson, Mr. Ennis Hastings    0  29.5      0
# 733               2                   Knight, Mr. Robert J    0  29.5      0
# 807               1                 Andrews, Mr. Thomas Jr    0  39.0      0
# 816               1                       Fry, Mr. Richard    0  42.0      0
# 823               1        Reuchlin, Jonkheer. John George    0  38.0      0
# 1158              1  Chisholm, Mr. Roderick Robert Crispin    0  42.0      0
# 1264              1                Ismay, Mr. Joseph Bruce    0  49.0      0
#
#              Parch  Ticket  Fare Cabin Embarked Title  Age_group  Family_size  \
# PassengerId
# 180              0    LINE   0.0     U        S    Mr          2            1
# 264              0  112059   0.0     K        S    Mr          2            1
# 272              0    LINE   0.0     U        S    Mr          1            1
# 278              0  239853   0.0     U        S    Mr          2            1
# 303              0    LINE   0.0     U        S    Mr          1            1
# 414              0  239853   0.0     U        S    Mr          2            1
# 467              0  239853   0.0     U        S    Mr          2            1
# 482              0  239854   0.0     U        S    Mr          2            1
# 598              0    LINE   0.0     U        S    Mr          3            1
# 634              0  112052   0.0     U        S    Mr          3            1
# 675              0  239856   0.0     U        S    Mr          2            1
# 733              0  239855   0.0     U        S    Mr          2            1
# 807              0  112050   0.0     K        S    Mr          2            1
# 816              0  112058   0.0     K        S    Mr          3            1
# 823              0   19972   0.0     U        S    Mr          2            1
# 1158             0  112051   0.0     U        S    Mr          3            1
# 1264             0  112058   0.0     K        S    Mr          3            1
#
#              Fam_gp  Identical_tickets  IT  Emb_gr
# PassengerId
# 180               2                  4   2       0
# 264               2                  1   1       0
# 272               2                  4   2       0
# 278               2                  3   2       0
# 303               2                  4   2       0
# 414               2                  3   2       0
# 467               2                  3   2       0
# 482               2                  1   1       0
# 598               2                  4   2       0
# 634               2                  1   1       0
# 675               2                  1   1       0
# 733               2                  1   1       0
# 807               2                  1   1       0
# 816               2                  2   2       0
# 823               2                  1   1       0
# 1158              2                  1   1       0
# 1264              2                  2   2       0

# %%
sns.histplot(test['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(data=test, x=test['Fare'], hue=test['Survived'], multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
df['Fare'] = df['Fare'] / df['Identical_tickets']
df['Fare'] = df['Fare'].map(lambda n: np.log(n) if n > 0 else 0)

# %% [markdown]
# ---
# С признаками все
# ---
# ---

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pclass             1309 non-null   int64
#  1   Name               1309 non-null   object
#  2   Sex                1309 non-null   int64
#  3   Age                1309 non-null   float64
#  4   SibSp              1309 non-null   int64
#  5   Parch              1309 non-null   int64
#  6   Ticket             1309 non-null   object
#  7   Fare               1309 non-null   float64
#  8   Cabin              1309 non-null   object
#  9   Embarked           1309 non-null   object
#  10  Title              1309 non-null   object
#  11  Age_group          1309 non-null   int64
#  12  Family_size        1309 non-null   int64
#  13  Fam_gp             1309 non-null   int64
#  14  Identical_tickets  1309 non-null   int64
#  15  IT                 1309 non-null   int64
#  16  Emb_gr             1309 non-null   int64
# dtypes: float64(2), int64(10), object(5)
# memory usage: 216.4+ KB
#              Pclass                                               Name  Sex  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris    0
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 3                 3                             Heikkinen, Miss. Laina    1
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 5                 3                           Allen, Mr. William Henry    0
#
#               Age  SibSp  Parch            Ticket      Fare Cabin Embarked  \
# PassengerId
# 1            22.0      1      0         A/5 21171  1.981001     U        S
# 2            38.0      1      0          PC 17599  3.573515     K        C
# 3            26.0      0      0  STON/O2. 3101282  2.070022     U        S
# 4            35.0      1      0            113803  3.279030     K        S
# 5            35.0      0      0            373450  2.085672     U        S
#
#             Title  Age_group  Family_size  Fam_gp  Identical_tickets  IT  \
# PassengerId
# 1              Mr          1            2       3                  1   1
# 2            Miss          2            2       3                  2   2
# 3            Miss          1            1       2                  1   1
# 4            Miss          2            2       3                  2   2
# 5              Mr          2            1       2                  1   1
#
#              Emb_gr
# PassengerId
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# 5                 0

# %%
test.drop(columns=['Name', 'Ticket', 'Title'], axis=1, inplace=True)
df.drop(columns=['Name', 'Ticket', 'Title'], axis=1, inplace=True)

# %%
sns.histplot(data = test, x = 'Fare', bins = 10);

# %%
test.head()
# Out:
#              Pclass  Sex   Age  SibSp  Parch      Fare Cabin Embarked  \
# PassengerId
# 1                 3    0  22.0      1      0  1.981001     U        S
# 2                 1    1  38.0      1      0  4.266662     K        C
# 3                 3    1  26.0      0      0  2.070022     U        S
# 4                 1    1  35.0      1      0  3.279030     K        S
# 5                 3    0  35.0      0      0  2.085672     U        S
#
#              Age_group  Family_size  Survived  Fam_gp  Identical_tickets  IT  \
# PassengerId
# 1                    1            2         0       3                  1   1
# 2                    2            2         1       3                  1   1
# 3                    1            1         1       2                  1   1
# 4                    2            2         1       3                  2   2
# 5                    2            1         0       2                  1   1
#
#              Emb_gr
# PassengerId
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# 5                 0

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(test.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# Доработка признаков
# ---
# ---

# %%
df.head()
# Out:
#              Pclass  Sex   Age  SibSp  Parch      Fare Cabin Embarked  \
# PassengerId
# 1                 3    0  22.0      1      0  1.981001     U        S
# 2                 1    1  38.0      1      0  3.573515     K        C
# 3                 3    1  26.0      0      0  2.070022     U        S
# 4                 1    1  35.0      1      0  3.279030     K        S
# 5                 3    0  35.0      0      0  2.085672     U        S
#
#              Age_group  Family_size  Fam_gp  Identical_tickets  IT  Emb_gr
# PassengerId
# 1                    1            2       3                  1   1       0
# 2                    2            2       3                  2   2       1
# 3                    1            1       2                  1   1       0
# 4                    2            2       3                  2   2       0
# 5                    2            1       2                  1   1       0

# %%
coll_tr = ['Age', 'SibSp', 'Parch', 'Family_size']
ss = StandardScaler()
test[coll_tr] = ss.fit_transform(test[coll_tr])

# %%
test.head()
# Out:
#              Pclass  Sex       Age     SibSp     Parch      Fare Cabin  \
# PassengerId
# 1                 3    0 -0.539232  0.432793 -0.473674  1.981001     U
# 2                 1    1  0.661032  0.432793 -0.473674  4.266662     K
# 3                 3    1 -0.239166 -0.474545 -0.473674  2.070022     U
# 4                 1    1  0.435982  0.432793 -0.473674  3.279030     K
# 5                 3    0  0.435982 -0.474545 -0.473674  2.085672     U
#
#             Embarked  Age_group  Family_size  Survived  Fam_gp  \
# PassengerId
# 1                  S          1     0.059160         0       3
# 2                  C          2     0.059160         1       3
# 3                  S          1    -0.560975         1       2
# 4                  S          2     0.059160         1       3
# 5                  S          2    -0.560975         0       2
#
#              Identical_tickets  IT  Emb_gr
# PassengerId
# 1                            1   1       0
# 2                            1   1       1
# 3                            1   1       0
# 4                            2   2       0
# 5                            1   1       0

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(test.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
test.groupby('Age_group', sort=True).mean()['Survived']
# Out:
# Age_group
# 0    0.591549
# 1    0.330846
# 2    0.427451
# 3    0.370968
# 4    0.343750
# 5    0.142857
# Name: Survived, dtype: float64

# %%
test['Child'] = 0
test.loc[test['Age_group'] == 0, 'Child'] = 1
test['Old'] = 0
test.loc[test['Age_group'] == 5, 'Old'] = 1
test.loc[(test['Age_group'] > 0) & (test['Age_group'] < 5), 'Age_group'] = 1
test.loc[test['Age_group'] != 1, 'Age_group'] = 0

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(test.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
col = ['Pclass', 'Sex', 'Fare', 'Cabin', 'IT', 'Survived']
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(test[col].corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
le = LabelEncoder()
df['Cabin'] = le.fit_transform(df['Cabin'])

df['Child'] = 0
df.loc[df['Age_group'] == 0, 'Child'] = 1
df.loc[(df['Age_group'] > 0) & (df['Age_group'] < 5), 'Age_group'] = 1
df.loc[df['Age_group'] != 1, 'Age_group'] = 0

# %%
col.remove('Survived')
df_1 = df[col].copy()

# %%
train_1, task_1 = df_1[:len(train)], df_1[len(train):]

# %%
train_1.info()
train_1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    int64
#  2   Fare    891 non-null    float64
#  3   Cabin   891 non-null    int64
#  4   IT      891 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 41.8 KB
#              Pclass  Sex      Fare  Cabin  IT
# PassengerId
# 1                 3    0  1.981001      1   1
# 2                 1    1  3.573515      0   2
# 3                 3    1  2.070022      1   1
# 4                 1    1  3.279030      0   2
# 5                 3    0  2.085672      1   1

# %% [markdown]
# ----
# ML - LR
# ---

# %%
lr = LogisticRegression(max_iter=50)

# %%
lr.fit(train_1, y_train_mean)
# Out:
# LogisticRegression(max_iter=50)

# %%
y_pred_1 = lr.predict(task_1)

# %%
out = pd.DataFrame({'PassengerId': task_1.index, 'Survived': y_pred_1})
out.to_csv('lr_03_29.csv', index=False)

# %%
params = {
    'max_iter': [50, 100, 200, 400]
}

lr = LogisticRegression()
gs_lr = GridSearchCV(lr, params, 
                     n_jobs=-1,
                     cv=5, 
            
                     )

gs_lr.fit(train_1, y_train_mean)

gs_lr.best_estimator_, gs_lr.score(train_1, y_train_mean), gs_lr.score(train_1, y_train_mean)
# Out:
# (LogisticRegression(max_iter=50), 0.8047138047138047, 0.8047138047138047)

# %%
y_answer_1 = gs_lr.predict(task_1)
output = pd.DataFrame({'PassengerId': task_1.index, 'Survived': y_answer_1})
output.to_csv('gs_lr.csv', index=False)

# %% [markdown]
# ---
# ML ML ML ML ML
# --
# ---

# %%
def evaluate_preds(true_values, pred_values, save=False):
    """Оценка качества модели и график preds vs true"""
    
    print("R2:\t" + str(round(r2(true_values, pred_values), 3)) + "\n" +
          "RMSE:\t" + str(round(np.sqrt(mse(true_values, pred_values)), 3)) + "\n" +
          "MSE:\t" + str(round(mse(true_values, pred_values), 3))
         )
    
#     plt.figure(figsize=(8,8))
    
#     sns.scatterplot(x=pred_values, y=true_values)
#     plt.plot([0, 500000], [0, 500000], linestyle='--', color='black')  # диагональ, где true_values = pred_values
    
#     plt.xlabel('Predicted values')
#     plt.ylabel('True values')
#     plt.title('True vs Predicted values')
    
#     if save == True:
#         plt.savefig(REPORTS_FILE_PATH + 'report.png')
#     plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(train_1, y_train_mean, test_size=0.33, random_state=21)

# %%
gb_model = GradientBoostingClassifier(
                                     max_depth=7,
                                     min_samples_leaf=10, 
                                     n_estimators=500)
gb_model.fit(X_train, y_train)

y_train_preds = gb_model.predict(X_train)

evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.708
# RMSE:	0.262
# MSE:	0.069

# %%
param = [
    {'n_estimators': [100, 200, 300, 400, 450, 500], 
     'max_depth': [3, 4, 6, 8, 10, 12], 
     'max_leaf_nodes': [15, 20, 25]}, 
]


rf = RandomForestClassifier()
gs_rf = GridSearchCV(rf, param, cv = 5, n_jobs = -1, verbose = 1)
gs_rf.fit(X_train, y_train)

rf_best = gs_rf.best_estimator_
gs_rf.best_estimator_, gs_rf.score(X_test, y_test), gs_rf.score(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# (RandomForestClassifier(max_depth=8, max_leaf_nodes=25, n_estimators=400),
#  0.823728813559322,
#  0.8825503355704698)

# %%
param_gb = [
    {
        'n_estimators': range(12, 36, 4), 
        'max_depth': range(3, 20, 4),
        'max_leaf_nodes': range(8, 28, 4)
    }
]

gb = GradientBoostingClassifier()
gs_gb = GridSearchCV(gb, param_gb, cv = 5, n_jobs = -1, verbose = 1)
gs_gb.fit(X_train, y_train)

gs_gb.best_estimator_, gs_gb.score(X_test, y_test), gs_gb.score(X_train, y_train)
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# (GradientBoostingClassifier(max_depth=15, max_leaf_nodes=16, n_estimators=32),
#  0.8169491525423729,
#  0.9093959731543624)

# %% [markdown]
# ---
# ANSWER
# ---
# ---

# %%
# y_answer_1 = gs_gb.predict(task_1)
# output = pd.DataFrame({'PassengerId': task_1.index, 'Survived': y_answer_1})
# output.to_csv('submission.csv', index=False)
# Out:
# /Users/igarg/.brew/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Age_group
# - Emb_gr
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [751], in <module>
# ----> 1 y_answer_1 = gs_gb.predict(task_1)
#       2 output = pd.DataFrame({'PassengerId': task_1.index, 'Survived': y_answer_1})
#       3 output.to_csv('submission.csv', index=False)
#
# File ~/.brew/lib/python3.9/site-packages/sklearn/utils/metaestimators.py:113, in _AvailableIfDescriptor.__get__.<locals>.<lambda>(*args, **kwargs)
#     110         raise attr_err
#     112     # lambda, but not partial, allows help() to work with update_wrapper
# --> 113     out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114 else:
#     116     def fn(*args, **kwargs):
#
# File ~/.brew/lib/python3.9/site-packages/sklearn/model_selection/_search.py:521, in BaseSearchCV.predict(self, X)
#     503 """Call predict on the estimator with the best found parameters.
#     504
#     505 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     518     the best found parameters.
#     519 """
#     520 check_is_fitted(self)
# --> 521 return self.best_estimator_.predict(X)
#
# File ~/.brew/lib/python3.9/site-packages/sklearn/ensemble/_gb.py:1359, in GradientBoostingClassifier.predict(self, X)
#    1344 def predict(self, X):
#    1345     """Predict class for X.
#    1346
#    1347     Parameters
#    (...)
#    1357         The predicted values.
#    1358     """
# -> 1359     raw_predictions = self.decision_function(X)
#    1360     encoded_labels = self.loss_._raw_prediction_to_decision(raw_predictions)
#    1361     return self.classes_.take(encoded_labels, axis=0)
#
# File ~/.brew/lib/python3.9/site-packages/sklearn/ensemble/_gb.py:1312, in GradientBoostingClassifier.decision_function(self, X)
#    1293 def decision_function(self, X):
#    1294     """Compute the decision function of ``X``.
#    1295
#    1296     Parameters
#    (...)
#    1310         array of shape (n_samples,).
#    1311     """
# -> 1312     X = self._validate_data(
#    1313         X, dtype=DTYPE, order="C", accept_sparse="csr", reset=False
#    1314     )
#    1315     raw_predictions = self._raw_predict(X)
#    1316     if raw_predictions.shape[1] == 1:
#
# File ~/.brew/lib/python3.9/site-packages/sklearn/base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File ~/.brew/lib/python3.9/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 8 features, but GradientBoostingClassifier is expecting 6 features as input.

# %% [markdown]
# ---

# %%
df.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked',
#        'Age_group', 'Family_size', 'Fam_gp', 'Identical_tickets', 'IT',
#        'Emb_gr', 'Child'],
#       dtype='object')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(test.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pclass             1309 non-null   int64
#  1   Sex                1309 non-null   int64
#  2   Age                1309 non-null   float64
#  3   SibSp              1309 non-null   float64
#  4   Parch              1309 non-null   float64
#  5   Fare               1309 non-null   float64
#  6   Cabin              1309 non-null   int64
#  7   Embarked           1309 non-null   object
#  8   Age_group          1309 non-null   int64
#  9   Family_size        1309 non-null   float64
#  10  Fam_gp             1309 non-null   int64
#  11  Identical_tickets  1309 non-null   int64
#  12  IT                 1309 non-null   int64
#  13  Emb_gr             1309 non-null   int64
#  14  Child              1309 non-null   int64
# dtypes: float64(5), int64(9), object(1)
# memory usage: 195.9+ KB

# %%
coll_tr = ['Age', 'SibSp', 'Parch', 'Family_size']
ss = StandardScaler()
df[coll_tr] = ss.fit_transform(df[coll_tr])

# %% [markdown]
# ------

# %%
col = ['Pclass', 'Sex', 'Fare', 'Cabin', 'IT', 'Emb_gr', 'Fam_gp']
df_2 = df[col].copy()
train_2, task_2 = df_2[:len(train)], df_2[len(train):]

# %%
train_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pclass     891 non-null    int64
#  1   Sex        891 non-null    int64
#  2   Fare       891 non-null    float64
#  3   Cabin      891 non-null    int64
#  4   IT         891 non-null    int64
#  5   Child      891 non-null    int64
#  6   Age_group  891 non-null    int64
#  7   Emb_gr     891 non-null    int64
#  8   Fam_gp     891 non-null    int64
# dtypes: float64(1), int64(8)
# memory usage: 69.6 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(train_2, y_train_mean, test_size=0.33, random_state=21)

# %%
param = [
    {'n_estimators': range(12, 30, 2), 
     'max_depth': range(5, 15, 2), 
     'max_leaf_nodes': range(15, 25, 2)}, 
]


rf = RandomForestClassifier()
gs_rf = GridSearchCV(rf, param, cv = 5, n_jobs = -1, verbose = 1)
gs_rf.fit(X_train, y_train)

rf_best = gs_rf.best_estimator_
gs_rf.best_estimator_, gs_rf.score(X_test, y_test), gs_rf.score(X_train, y_train)
# Out:
# Fitting 5 folds for each of 225 candidates, totalling 1125 fits
# (RandomForestClassifier(max_depth=11, max_leaf_nodes=21, n_estimators=20),
#  0.7932203389830509,
#  0.87248322147651)

# %%
param_gb = [
    {'n_estimators': range(12, 36, 4), 
     'max_depth': range(8, 24, 4),
     'max_leaf_nodes': range(8, 28, 4),
    }
]

gb = GradientBoostingClassifier()
gs_gb = GridSearchCV(gb, param_gb, cv = 5, n_jobs = -1, verbose = 1)
gs_gb.fit(X_train, y_train)

gs_gb.best_estimator_, gs_gb.score(X_test, y_test), gs_gb.score(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# (GradientBoostingClassifier(max_depth=8, max_leaf_nodes=20, n_estimators=28),
#  0.8271186440677966,
#  0.9177852348993288)

# %%
param = [
    {'n_estimators': range(8, 28, 4), 
     'max_depth': range(24, 48, 4),
     'max_leaf_nodes': range(20, 48, 4),
    }
]

et = ExtraTreesClassifier()
gs_et = GridSearchCV(et, param, cv = 5, n_jobs = -1, verbose = 1)
gs_et.fit(X_train, y_train)

et_best = gs_et.best_estimator_
gs_et.best_estimator_, gs_et.score(X_test, y_test), gs_et.score(X_train, y_train)
# Out:
# Fitting 5 folds for each of 210 candidates, totalling 1050 fits
# (ExtraTreesClassifier(max_depth=24, max_leaf_nodes=44, n_estimators=24),
#  0.8101694915254237,
#  0.8691275167785235)

# %%
y_answer_2 = gs_et.predict(task_2)
output = pd.DataFrame({'PassengerId': task_2.index, 'Survived': y_answer_2})
output.to_csv('submission.csv', index=False)
